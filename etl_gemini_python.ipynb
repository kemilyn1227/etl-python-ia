# %%
df.to_excel("resultado.xlsx", index=False)

# %%
df
# Out:
#        nome  idade     interesses     modalidade  \
# 0   KEMILYN     23            BTS           KPOP
# 1     JIMIN     28  JUSTIN BIEBER  CONTEMPORÂNEO
# 2  JUNGKOOK     26     ED SHEERAN          HIHOP
#
#                               mensagem_personalizada
# 0  Olá, KEMILYN!  Com seus 23 anos, você tem uma ...
# 1  E aí, Jimin!  Com 28 anos e no contemporâneo, ...
# 2  E aí, Jungkook!  Com 26 anos e essa paixão pel...

# %%
mensagens = []

for index, row in df.iterrows():

    mensagem = gerar_mensagem(
        row["nome"],
        row["idade"],
        row["interesses"],
        row["modalidade"]
    )

    mensagens.append(mensagem)

df["mensagem_personalizada"] = mensagens

# %%
def gerar_mensagem(nome,idade,interesses,modalidade):

  prompt= f"""
  Voce é um profissional na area da danca , crie uma mensagem de motivacao personalizada curta e amigavel para

  Nome:{nome}
  Idade: {idade}
  Interesses:{interesses}
  Modalidade:{modalidade}
  """

  resposta = model.generate_content(prompt)

  return resposta.text.replace("\n", " ")

# %%
df = pd.read_excel("/Alunos.xlsx")

df.head()
# Out:
#        nome  idade     interesses     modalidade
# 0   KEMILYN     23            BTS           KPOP
# 1     JIMIN     28  JUSTIN BIEBER  CONTEMPORÂNEO
# 2  JUNGKOOK     26     ED SHEERAN          HIHOP

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
genai.configure(api_key="AIzaSyCIZx2iOByi1xnSSyhKCBmOH8QJ6ywLQrE")

# %%
import pandas as pd
import google.generativeai as genai

# %%
# !pip install google-generativeai pandas openpyxl
